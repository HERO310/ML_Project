# %% [markdown]
# # ICE-LoRA Setup Notebook
# ### Install dependencies and load datasets

# %%
# !pip install torch transformers datasets peft tqdm

# %%
from datasets import load_dataset
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('gpt2')
dataset = load_dataset('json', data_files={'train': 'data/zsre_train.json', 'test': 'data/zsre_test.json'})
print(dataset)
